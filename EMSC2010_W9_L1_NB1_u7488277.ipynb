# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoFairley123/EMSC2010-WK9.1/blob/main/EMSC2010_W9_L1_NB1_u7488277.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W9-L1-NB1
# Model Earth's surface temperature (in Kelvin) using a zero-dimensional energy balance model without an atmosphere.
#
# $T_e = \left[ \frac{S}{4 \alpha} (1-A)\right]^{1/4}$
#
# where:
# * $T_e$ is Earth's surface temperature in Kelvin
# * $S$ is the solar flux (1366 W/m$^2$)
# * $A$ is albedo (currently around 0.3)
# * $\alpha$ is the Stefan-Boltmann constant (5.67E-8 W/m$^2$/K$^4$)

# %%
# Define constants
solar_flux = 1366*0.9
albedo = 0.3
stefan_boltzmann = 5.67E-8

# %%
# Calculate Earth's surface temperature in Kelvin
T_e = ((solar_flux/(4*stefan_boltzmann))*(1-albedo))**(1/4)
print(f"{T_e} Kelvin")
# Convert Kelvin to Degrees Celcius
T_celsius = T_e - 273.15
print(f"{T_celsius} Degrees Celsius")
# Out:
# 248.19158334222595 Kelvin
# -24.958416657774023 Degrees Celsius
